# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
import datetime as dt

# %%
import json
import requests
import datetime as dt
url = 'https://api.binance.com/api/v3/klines'
symbol = 'BTCUSDT'
interval = '1h'
start = str(int(dt.datetime(2022,8,1).timestamp()*1000)) #data start from: 2017,8,16
end = str(int(dt.datetime(2022,9,1).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 1000}
btc = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc.datetime]
btc=btc.astype(float)
btc.head()
# Out:
#                          datetime     close
# 2022-08-01 00:00:00  1.659326e+12  23392.40
# 2022-08-01 01:00:00  1.659330e+12  23327.47
# 2022-08-01 02:00:00  1.659334e+12  23223.77
# 2022-08-01 03:00:00  1.659337e+12  23322.05
# 2022-08-01 04:00:00  1.659341e+12  23287.76

# %% [markdown]
# adding 5 months of data (loading the data separatly, idk but the api only let load max 1000 obs at once)

# %%
start2 = str(int(dt.datetime(2022,9,1).timestamp()*1000))
end2 = str(int(dt.datetime(2022,10,1).timestamp()*1000))
par2 = {'symbol': symbol, 'interval': interval, 'startTime': start2, 'endTime': end2, 'limit': 1000}
btc2 = pd.DataFrame(json.loads(requests.get(url, params= par2).text))
btc2.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc2.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc2 = btc2.drop(btc2.index[0])
btc2.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc2.datetime]
btc2=btc2.astype(float)
btc2.head()
# Out:
#                          datetime     close
# 2022-09-01 01:00:00  1.662008e+12  20038.97
# 2022-09-01 02:00:00  1.662012e+12  19982.50
# 2022-09-01 03:00:00  1.662016e+12  19895.66
# 2022-09-01 04:00:00  1.662019e+12  19928.09
# 2022-09-01 05:00:00  1.662023e+12  19934.57

# %%
start3 = str(int(dt.datetime(2022,10,1).timestamp()*1000))
end3 = str(int(dt.datetime(2022,11,1).timestamp()*1000))
par3 = {'symbol': symbol, 'interval': interval, 'startTime': start3, 'endTime': end3, 'limit': 1000}
btc3 = pd.DataFrame(json.loads(requests.get(url, params= par3).text))
btc3.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc3.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc3 = btc3.drop(btc3.index[0])
btc3.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc3.datetime]
btc3=btc3.astype(float)
btc3.head()
# Out:
#                          datetime     close
# 2022-10-01 01:00:00  1.664597e+12  19407.43
# 2022-10-01 02:00:00  1.664600e+12  19317.92
# 2022-10-01 03:00:00  1.664604e+12  19292.82
# 2022-10-01 04:00:00  1.664608e+12  19309.84
# 2022-10-01 05:00:00  1.664611e+12  19335.03

# %%
start4 = str(int(dt.datetime(2022,11,1).timestamp()*1000))
end4 = str(int(dt.datetime(2022,12,1).timestamp()*1000))
par4 = {'symbol': symbol, 'interval': interval, 'startTime': start4, 'endTime': end4, 'limit': 1000}
btc4 = pd.DataFrame(json.loads(requests.get(url, params= par4).text))
btc4.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc4.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc4 = btc4.drop(btc4.index[0])
btc4.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc4.datetime]
btc4=btc4.astype(float)
btc4.head()
# Out:
#                          datetime     close
# 2022-11-01 01:00:00  1.667275e+12  20495.53
# 2022-11-01 02:00:00  1.667279e+12  20530.41
# 2022-11-01 03:00:00  1.667282e+12  20624.57
# 2022-11-01 04:00:00  1.667286e+12  20599.51
# 2022-11-01 05:00:00  1.667290e+12  20584.63

# %%
start5 = str(int(dt.datetime(2022,12,1).timestamp()*1000))
end5 = str(int(dt.datetime(2022,12,30).timestamp()*1000))
par5 = {'symbol': symbol, 'interval': interval, 'startTime': start5, 'endTime': end5, 'limit': 1000}
btc5 = pd.DataFrame(json.loads(requests.get(url, params= par5).text))
btc5.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc5.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc5 = btc5.drop(btc5.index[0])
btc5.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc5.datetime]
btc5=btc5.astype(float)
btc5.head()
btc5.head()
# Out:
#                          datetime     close
# 2022-12-01 01:00:00  1.669867e+12  17142.23
# 2022-12-01 02:00:00  1.669871e+12  17110.11
# 2022-12-01 03:00:00  1.669874e+12  17120.89
# 2022-12-01 04:00:00  1.669878e+12  17070.21
# 2022-12-01 05:00:00  1.669882e+12  17110.79

# %%
start6 = str(int(dt.datetime(2022,12,30).timestamp()*1000))
end6 = str(int(dt.datetime(2023,1,30).timestamp()*1000))
par6 = {'symbol': symbol, 'interval': interval, 'startTime': start6, 'endTime': end6, 'limit': 1000}
btc6 = pd.DataFrame(json.loads(requests.get(url, params= par6).text))
btc6.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc6.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc6 = btc6.drop(btc6.index[0])
btc6.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc6.datetime]
btc6=btc6.astype(float)
btc6.head()
# Out:
#                          datetime     close
# 2022-12-30 01:00:00  1.672373e+12  16613.79
# 2022-12-30 02:00:00  1.672376e+12  16554.39
# 2022-12-30 03:00:00  1.672380e+12  16544.94
# 2022-12-30 04:00:00  1.672384e+12  16474.93
# 2022-12-30 05:00:00  1.672387e+12  16500.24

# %%
btc = btc.append(btc2)
btc = btc.append(btc3)
btc = btc.append(btc4)
btc = btc.append(btc5)
btc = btc.append(btc6)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13084\2122435420.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc2)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13084\2122435420.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc3)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13084\2122435420.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc4)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13084\2122435420.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc5)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13084\2122435420.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc6)

# %% [markdown]
# algo

# %%
btc['10d-ma'] = btc['close'].rolling(10).mean().shift()
btc['20d-ma'] = btc['close'].rolling(20).mean().shift()

# %% [markdown]
# algo (entries)

# %%
btc['signal'] = np.where(btc['10d-ma'] > btc['20d-ma'], 1, 0) #long signal
btc['signal'] = np.where(btc['10d-ma'] < btc['20d-ma'], -1, btc['signal']) #short signal
btc.dropna(inplace = True)
btc['entry'] =  btc.signal.diff()

# %% [markdown]
# returns

# %%
btc['return'] = np.log(btc['close']).diff()
btc['algo_return'] = btc['signal'] * btc['return']
btc['entry'] =  btc.signal.diff()
btc.head()
# Out:
#                          datetime     close     10d-ma      20d-ma  signal  \
# 2022-08-01 20:00:00  1.659398e+12  23187.65  23140.449  23195.9880      -1
# 2022-08-01 21:00:00  1.659402e+12  22997.14  23115.473  23185.7505      -1
# 2022-08-01 22:00:00  1.659406e+12  22912.95  23082.514  23169.2340      -1
# 2022-08-01 23:00:00  1.659409e+12  22853.11  23053.915  23153.6930      -1
# 2022-08-02 00:00:00  1.659413e+12  22862.28  23042.857  23130.2460      -1
#
#                      entry    return  algo_return
# 2022-08-01 20:00:00    NaN       NaN          NaN
# 2022-08-01 21:00:00    0.0 -0.008250     0.008250
# 2022-08-01 22:00:00    0.0 -0.003668     0.003668
# 2022-08-01 23:00:00    0.0 -0.002615     0.002615
# 2022-08-02 00:00:00    0.0  0.000401    -0.000401

# %%
plt.rcParams['figure.figsize'] = 19, 9
plt.grid(True, alpha = .3)
plt.plot(btc.iloc[-180:]['close'], label = 'btc')
plt.plot(btc.iloc[-180:]['10d-ma'], label = '10d-ma')
plt.plot(btc.iloc[-180:]['20d-ma'], label = '20d-ma')
plt.plot(btc[-180:].loc[btc.entry == 2].index, btc[-180:]['close'][btc.entry == 2], '^', color = 'g', markersize = 8)
plt.plot(btc[-180:].loc[btc.entry == -2].index, btc[-180:]['close'][btc.entry == -2], 'v', color = 'r', markersize = 8)
plt.legend(loc=2);

# %% [markdown]
# performance

# %%
plt.plot(np.exp(btc['return']).cumprod(), label='buy and hold performance')
plt.plot(np.exp(btc['algo_return']).cumprod(), label='algo performance')
plt.legend(loc=2)
plt.grid(True, alpha=.3)
plt.savefig("btcma_performance.jpg")

# %% [markdown]
# buy n hold returns (%)

# %%
(np.exp(btc['return']).cumprod()[-1] - 1) *100   #[-1] -> last day of returns
# Out:
# -27.446852095835638

# %% [markdown]
# system returns (%)

# %%
(np.exp(btc['algo_return']).cumprod()[-1] - 1) *100
# Out:
# 43.46140654688331
