# %%
import pandas as pd
import pandas_datareader as pdr
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,5
import seaborn as sb
sb.set()

# %%
import json
import requests
import datetime as dt

url = 'https://api.binance.com/api/v3/klines'
symbol = 'BTCUSDT'
interval = '1h'
start = str(int(dt.datetime(2022,8,1).timestamp()*1000))  #data start from: 2017,8,16
end = str(int(dt.datetime(2022,9,1).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 5000}
btc = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc.datetime]
btc=btc.astype(float)
btc.head()
# Out:
#                          datetime     close
# 2022-08-01 00:00:00  1.659326e+12  23392.40
# 2022-08-01 01:00:00  1.659330e+12  23327.47
# 2022-08-01 02:00:00  1.659334e+12  23223.77
# 2022-08-01 03:00:00  1.659337e+12  23322.05
# 2022-08-01 04:00:00  1.659341e+12  23287.76

# %% [markdown]
# adding 5 months of data

# %%
start = str(int(dt.datetime(2022,9,1).timestamp()*1000))
end = str(int(dt.datetime(2022,10,1).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 1000}
btc2 = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc2.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc2.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc2 = btc2.drop(btc2.index[0])
btc2.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc2.datetime]
btc2=btc2.astype(float)
btc2.head()
# Out:
#                          datetime     close
# 2022-09-01 01:00:00  1.662008e+12  20038.97
# 2022-09-01 02:00:00  1.662012e+12  19982.50
# 2022-09-01 03:00:00  1.662016e+12  19895.66
# 2022-09-01 04:00:00  1.662019e+12  19928.09
# 2022-09-01 05:00:00  1.662023e+12  19934.57

# %%
start = str(int(dt.datetime(2022,10,1).timestamp()*1000))
end = str(int(dt.datetime(2022,11,1).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 1000}
btc3 = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc3.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc3.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc3 = btc3.drop(btc3.index[0])
btc3.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc3.datetime]
btc3=btc3.astype(float)
btc3.head()
# Out:
#                          datetime     close
# 2022-10-01 01:00:00  1.664597e+12  19407.43
# 2022-10-01 02:00:00  1.664600e+12  19317.92
# 2022-10-01 03:00:00  1.664604e+12  19292.82
# 2022-10-01 04:00:00  1.664608e+12  19309.84
# 2022-10-01 05:00:00  1.664611e+12  19335.03

# %%
start = str(int(dt.datetime(2022,11,1).timestamp()*1000))
end = str(int(dt.datetime(2022,12,1).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 1000}
btc4 = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc4.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc4.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc4 = btc4.drop(btc4.index[0])
btc4.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc4.datetime]
btc4=btc4.astype(float)
btc4.head()
# Out:
#                          datetime     close
# 2022-11-01 01:00:00  1.667275e+12  20495.53
# 2022-11-01 02:00:00  1.667279e+12  20530.41
# 2022-11-01 03:00:00  1.667282e+12  20624.57
# 2022-11-01 04:00:00  1.667286e+12  20599.51
# 2022-11-01 05:00:00  1.667290e+12  20584.63

# %%
start = str(int(dt.datetime(2022,12,1).timestamp()*1000))
end = str(int(dt.datetime(2022,12,30).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 1000}
btc5 = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc5.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc5.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc5 = btc5.drop(btc5.index[0])
btc5.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc5.datetime]
btc5=btc5.astype(float)
btc5.head()
# Out:
#                          datetime     close
# 2022-12-01 01:00:00  1.669867e+12  17142.23
# 2022-12-01 02:00:00  1.669871e+12  17110.11
# 2022-12-01 03:00:00  1.669874e+12  17120.89
# 2022-12-01 04:00:00  1.669878e+12  17070.21
# 2022-12-01 05:00:00  1.669882e+12  17110.79

# %%
start = str(int(dt.datetime(2022,12,30).timestamp()*1000))
end = str(int(dt.datetime(2023,1,30).timestamp()*1000))
par = {'symbol': symbol, 'interval': interval, 'startTime': start, 'endTime': end, 'limit': 1000}
btc6 = pd.DataFrame(json.loads(requests.get(url, params= par).text))
btc6.columns = ['datetime', 'open', 'high', 'low', 'close', 'volume','close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore']
btc6.drop(columns=['open', 'high', 'low', 'volume', 'close_time', 'qav', 'num_trades','taker_base_vol', 'taker_quote_vol', 'ignore'], inplace = True) #we will only use close price
btc6 = btc6.drop(btc6.index[0])
btc6.index = [dt.datetime.fromtimestamp(x/1000.0) for x in btc6.datetime]
btc6=btc6.astype(float)
btc6.head()
# Out:
#                          datetime     close
# 2022-12-30 01:00:00  1.672373e+12  16613.79
# 2022-12-30 02:00:00  1.672376e+12  16554.39
# 2022-12-30 03:00:00  1.672380e+12  16544.94
# 2022-12-30 04:00:00  1.672384e+12  16474.93
# 2022-12-30 05:00:00  1.672387e+12  16500.24

# %%
btc = btc.append(btc2)
btc = btc.append(btc3)
btc = btc.append(btc4)
btc = btc.append(btc5)
btc = btc.append(btc6)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15840\2122435420.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc2)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15840\2122435420.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc3)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15840\2122435420.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc4)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15840\2122435420.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc5)
# C:\Users\Acer\AppData\Local\Temp\ipykernel_15840\2122435420.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   btc = btc.append(btc6)

# %% [markdown]
# algo

# %%
ma = 10
btc['returns'] = np.log(btc["close"]).diff()
btc['ma'] = btc['close'].rolling(ma).mean()
btc['ratio'] = btc['close'] / btc['ma']

# %%
percentiles = [4, 10, 50, 92.5, 96]
p = np.percentile(btc['ratio'].dropna(), percentiles)

# %%
btc['ratio'].dropna().plot(legend = True)
plt.axhline(p[0], c= (.5,.5,.5), ls='--')
plt.axhline(p[2], c= (.5,.5,.5), ls='--')
plt.axhline(p[-1], c= (.5,.5,.5), ls='--');

# %% [markdown]
# entries

# %%
short = p[-1]
long = p[0]
btc['position'] = np.where(btc.ratio > short, -1, np.nan)
btc['position'] = np.where(btc.ratio < long, 1, btc['position'])
btc['position'] = btc['position'].ffill()
plt.plot(btc.position.iloc[-1500:].dropna())

# %%
btc['10d-ma'] = btc['close'].rolling(5).mean().shift()
plt.rcParams['figure.figsize'] = 15, 7
plt.grid(True, alpha = .3)
plt.plot(btc.iloc[-180:]['close'], label = 'btc')
plt.plot(btc.iloc[-180:]['5d-ma'], label = '5d-ma')
plt.legend(loc=3);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '5d-ma'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 5
#       3 plt.grid(True, alpha = .3)
#       4 plt.plot(btc.iloc[-180:]['close'], label = 'btc')
# ----> 5 plt.plot(btc.iloc[-180:]['5d-ma'], label = '5d-ma')
#       6 plt.legend(loc=3);
#
# File C:\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File C:\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: '5d-ma'

# %% [markdown]
# performance

# %%
btc['algo_return'] = btc['returns'] * btc['position'].shift()

# %%
plt.plot(np.exp(btc['returns']).dropna().cumprod(), label='buy n hold' )
plt.plot(np.exp(btc['algo_return']).dropna().cumprod(), label='algo' )
plt.legend();

# %% [markdown]
# returns

# %% [markdown]
# buy n hold (%)

# %%
(np.exp(btc['returns']).dropna().cumprod()[-1] -1)*100

# %% [markdown]
# system (%)

# %%
(np.exp(btc['algo_return']).dropna().cumprod()[-1] -1)*100
